# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\KINGDAYVEED\Documents\messy_data.csv')

# %%
df.head(5)
# Out:
#    TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0     7402  03/17/2026      991     1045     Boo E       9  167.72   2935.06
# 1     5835  26-01-2035      741     1040    Book J      18  193.27   4386.52
# 2     2123  05/26/2035      933     1062     Bok N       5  126.39   1948.46
# 3     8789  28-02-2036      641     1060    Book I       6   66.98   1757.26
# 4      305  19-04-2023      123     1058    Book B      15   33.63   2578.19
#
#   PaymentType  CusterAge
# 0         NaN         87
# 1  debit card         69
# 2        Cash         15
# 3        Cash         22
# 4        Cash         -1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TrnsnID      10100 non-null  int64
#  1   Data         10100 non-null  object
#  2   CusmrID      10100 non-null  int64
#  3   ProdtID      10100 non-null  int64
#  4   ProdtName    9098 non-null   object
#  5   Qutity       10100 non-null  int64
#  6   Prize        10100 non-null  float64
#  7   TtlSales     10100 non-null  float64
#  8   PaymentType  8645 non-null   object
#  9   CusterAge    10100 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 789.2+ KB

# %%
df.describe()
# Out:
#             TrnsnID       CusmrID       ProdtID        Qutity         Prize  \
# count  10100.000000  10100.000000  10100.000000  10100.000000  10100.000000
# mean    5000.546634    503.805050   1049.607228      7.028119    102.397194
# std     2886.964892    289.143863     28.931014      7.207902     56.429556
# min        1.000000      1.000000   1000.000000     -5.000000      5.030000
# 25%     2504.750000    255.000000   1024.000000      1.000000     54.095000
# 50%     4998.500000    507.500000   1050.000000      7.000000    102.080000
# 75%     7502.250000    759.000000   1074.000000     13.000000    151.647500
# max    10000.000000    999.000000   1099.000000     19.000000    199.980000
#
#            TtlSales     CusterAge
# count  10100.000000  10100.000000
# mean    2521.484192     44.456832
# std     1431.601571     32.037813
# min       20.460000    -10.000000
# 25%     1288.860000     17.000000
# 50%     2520.870000     45.000000
# 75%     3755.747500     73.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 100

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 10099
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TrnsnID      10000 non-null  int64
#  1   Data         10000 non-null  object
#  2   CusmrID      10000 non-null  int64
#  3   ProdtID      10000 non-null  int64
#  4   ProdtName    9006 non-null   object
#  5   Qutity       10000 non-null  int64
#  6   Prize        10000 non-null  float64
#  7   TtlSales     10000 non-null  float64
#  8   PaymentType  8561 non-null   object
#  9   CusterAge    10000 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 859.4+ KB

# %%
df.describe()
# Out:
#            TrnsnID       CusmrID      ProdtID        Qutity         Prize  \
# count  10000.00000  10000.000000  10000.00000  10000.000000  10000.000000
# mean    5000.50000    504.449200   1049.63350      7.030800    102.363973
# std     2886.89568    289.181293     28.93976      7.209109     56.452674
# min        1.00000      1.000000   1000.00000     -5.000000      5.030000
# 25%     2500.75000    255.000000   1024.00000      1.000000     53.885000
# 50%     5000.50000    508.500000   1050.00000      7.000000    102.080000
# 75%     7500.25000    759.000000   1075.00000     13.000000    151.502500
# max    10000.00000    999.000000   1099.00000     19.000000    199.980000
#
#            TtlSales     CusterAge
# count  10000.000000  10000.000000
# mean    2521.596610     44.481600
# std     1431.303351     32.039943
# min       20.460000    -10.000000
# 25%     1290.127500     17.000000
# 50%     2519.960000     45.000000
# 75%     3756.700000     73.000000
# ...

# %%
#Check for and removing NaN or Null values

# %%
df.isnull()
# Out:
#        TrnsnID   Data  CusmrID  ProdtID  ProdtName  Qutity  Prize  TtlSales  \
# 0        False  False    False    False      False   False  False     False
# 1        False  False    False    False      False   False  False     False
# 2        False  False    False    False      False   False  False     False
# 3        False  False    False    False      False   False  False     False
# 4        False  False    False    False      False   False  False     False
# ...        ...    ...      ...      ...        ...     ...    ...       ...
# 10095    False  False    False    False      False   False  False     False
# 10096    False  False    False    False      False   False  False     False
# 10097    False  False    False    False      False   False  False     False
# 10098    False  False    False    False      False   False  False     False
# 10099    False  False    False    False      False   False  False     False
#
#        PaymentType  CusterAge
# ...

# %%
df['CusmrID'].isnull().sum()
# Out:
# 0

# %%
df['ProdtID'].isnull().sum()
# Out:
# 0

# %%
df['Qutity'].isnull().sum()
# Out:
# 0

# %%
df['Prize'].isnull().sum()
# Out:
# 0

# %%
df['CusterAge'].isnull().sum()
# Out:
# 0

# %%
df['Data'].isnull().sum()
# Out:
# 0

# %%
df['PaymentType'].isnull().sum()
# Out:
# 1439

# %%
df['PaymentType'].isnull()
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10095    False
# 10096    False
# 10097    False
# 10098    False
# 10099    False
# Name: PaymentType, Length: 10000, dtype: bool

# %%
df = df.dropna()

# %%
df['PaymentType'].isnull()
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 6        False
#          ...
# 10095    False
# 10096    False
# 10097    False
# 10098    False
# 10099    False
# Name: PaymentType, Length: 7706, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7706 entries, 1 to 10099
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TrnsnID      7706 non-null   int64
#  1   Data         7706 non-null   object
#  2   CusmrID      7706 non-null   int64
#  3   ProdtID      7706 non-null   int64
#  4   ProdtName    7706 non-null   object
#  5   Qutity       7706 non-null   int64
#  6   Prize        7706 non-null   float64
#  7   TtlSales     7706 non-null   float64
#  8   PaymentType  7706 non-null   object
#  9   CusterAge    7706 non-null   int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 662.2+ KB

# %%
df['TrnsnID'].isnull().sum()
# Out:
# 0

# %%
df['TtlSales'].isnull().sum()
# Out:
# 0

# %%
df.Data
# Out:
# 1        26-01-2035
# 2        05/26/2035
# 3        28-02-2036
# 4        19-04-2023
# 6        04/03/2031
#             ...
# 10095    04/03/2027
# 10096    08/16/2025
# 10097    06/18/2026
# 10098    04/08/2034
# 10099    26-04-2029
# Name: Data, Length: 7706, dtype: object

# %%
df.Data = df.Data.str.replace("-", "/")

# %%
df['Data'] = pd.to_datetime(df['Data'], errors='coerce', format='%m/%d/%Y').combine_first(
    pd.to_datetime(df['Data'], errors='coerce', format='%d-%m-%Y'))

# %%
df.Data = pd.to_datetime(df.Data, format = '%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7706 entries, 1 to 10099
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TrnsnID      7706 non-null   int64
#  1   Data         5365 non-null   datetime64[ns]
#  2   CusmrID      7706 non-null   int64
#  3   ProdtID      7706 non-null   int64
#  4   ProdtName    7706 non-null   object
#  5   Qutity       7706 non-null   int64
#  6   Prize        7706 non-null   float64
#  7   TtlSales     7706 non-null   float64
#  8   PaymentType  7706 non-null   object
#  9   CusterAge    7706 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(2)
# memory usage: 662.2+ KB

# %%
df = df.rename(columns={'TrnsnID': 'TransactionID', 'Data': 'Date', 'CusmrID': 'CustomerID', 'ProdtID': 'ProductID', 'ProdtName': 'ProductName', 'Qutity': 'Quantity', 'Prize': 'Price', 'TtlSales': 'TotalSales', 'CusterAge': 'CustomerAge'})

# %%
df.head(20)
# Out:
#     TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 1            5835        NaT         741       1040      Book J        18
# 2            2123 2035-05-26         933       1062       Bok N         5
# 3            8789        NaT         641       1060      Book I         6
# 4             305        NaT         123       1058      Book B        15
# 6            2996 2031-04-03         571       1086      Book D        15
# 7            7660        NaT         172       1012      Book P        12
# 9            4449 2030-02-05         614       1086      Book M         5
# 10           3621 2036-05-08         755       1051       Boo E        19
# 11           9211 2035-07-18         361       1020      Book O        14
# 12           5023 2032-04-10         626       1092      Book I         1
# 13           7924 2025-04-07         850       1075      Book T        10
# 14           4476 2029-12-12         559       1094      Book A        13
# ...

# %%
df.Date.values
# Out:
# array([                          'NaT', '2035-05-26T00:00:00.000000000',
#                                  'NaT', ...,
#        '2026-06-18T00:00:00.000000000', '2034-04-08T00:00:00.000000000',
#                                  'NaT'], dtype='datetime64[ns]')

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5365 entries, 2 to 10098
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  5365 non-null   int64
#  1   Date           5365 non-null   datetime64[ns]
#  2   CustomerID     5365 non-null   int64
#  3   ProductID      5365 non-null   int64
#  4   ProductName    5365 non-null   object
#  5   Quantity       5365 non-null   int64
#  6   Price          5365 non-null   float64
#  7   TotalSales     5365 non-null   float64
#  8   PaymentType    5365 non-null   object
#  9   CustomerAge    5365 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(2)
# memory usage: 461.1+ KB

# %%
df.head(25)
# Out:
#     TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 2            2123 2035-05-26         933       1062       Bok N         5
# 6            2996 2031-04-03         571       1086      Book D        15
# 9            4449 2030-02-05         614       1086      Book M         5
# 10           3621 2036-05-08         755       1051       Boo E        19
# 11           9211 2035-07-18         361       1020      Book O        14
# 12           5023 2032-04-10         626       1092      Book I         1
# 13           7924 2025-04-07         850       1075      Book T        10
# 14           4476 2029-12-12         559       1094      Book A        13
# 15           6709 2029-08-20         583       1044      Book T         8
# 17           3320 2032-08-16         180       1059      Book G        17
# 21           6283 2026-04-13         632       1049      Book P        12
# 23            501 2027-02-05         113       1069      Book R        12
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5365 entries, 2 to 10098
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  5365 non-null   int64
#  1   Date           5365 non-null   datetime64[ns]
#  2   CustomerID     5365 non-null   int64
#  3   ProductID      5365 non-null   int64
#  4   ProductName    5365 non-null   object
#  5   Quantity       5365 non-null   int64
#  6   Price          5365 non-null   float64
#  7   TotalSales     5365 non-null   float64
#  8   PaymentType    5365 non-null   object
#  9   CustomerAge    5365 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(2)
# memory usage: 461.1+ KB

# %%
df.PaymentType.value_counts()
# Out:
# PaymentType
# Credit Card    916
# Debit          914
# Credit         899
# debit card     891
# Cash           881
# paypal         864
# Name: count, dtype: int64

# %%
df.PaymentType = df.PaymentType.str.replace('Debit', 'Debit Card')

# %%
df.PaymentType = df.PaymentType.str.replace('debit card', 'Debit Card')

# %%
df.PaymentType = df.PaymentType.str.replace('Credit', 'Credit Card')

# %%
df.PaymentType = df.PaymentType.str.replace('Credit Card Card', 'Credit Card')

# %%
df.PaymentType = df.PaymentType.str.replace('paypal', 'Paypal')

# %%
df.PaymentType.value_counts()
# Out:
# PaymentType
# Credit Card    1815
# Debit Card     1805
# Cash            881
# Paypal          864
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5365 entries, 2 to 10098
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  5365 non-null   int64
#  1   Date           5365 non-null   datetime64[ns]
#  2   CustomerID     5365 non-null   int64
#  3   ProductID      5365 non-null   int64
#  4   ProductName    5365 non-null   object
#  5   Quantity       5365 non-null   int64
#  6   Price          5365 non-null   float64
#  7   TotalSales     5365 non-null   float64
#  8   PaymentType    5365 non-null   object
#  9   CustomerAge    5365 non-null   int64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(2)
# memory usage: 461.1+ KB

# %%
#Checking for and removing negative values in wrong places

# %%
df[df['TransactionID'] < 0]
# Out:
# Empty DataFrame
# Columns: [TransactionID, Date, CustomerID, ProductID, ProductName, Quantity, Price, TotalSales, PaymentType, CustomerAge]
# Index: []

# %%
df[df['CustomerID'] < 0]
# Out:
# Empty DataFrame
# Columns: [TransactionID, Date, CustomerID, ProductID, ProductName, Quantity, Price, TotalSales, PaymentType, CustomerAge]
# Index: []

# %%
df[df['ProductID'] < 0]
# Out:
# Empty DataFrame
# Columns: [TransactionID, Date, CustomerID, ProductID, ProductName, Quantity, Price, TotalSales, PaymentType, CustomerAge]
# Index: []

# %%
df[df['Quantity'] < 0]
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 26              4302 2029-12-10         566       1022       Bok N        -4
# 35              4429 2036-03-28         295       1057       Boo E        -4
# 50               316 2028-02-14         566       1012     Bookk H        -1
# 51              8616 2031-06-01         897       1004      Book M        -3
# 52              3527 2026-02-02         926       1051      Book B        -3
# ...              ...        ...         ...        ...         ...       ...
# 10065           7735 2026-10-11         620       1029       Bok N        -2
# 10074           2048 2029-04-08         637       1022      Book I        -3
# 10075           7850 2034-12-25         678       1005      Book S        -5
# 10094           6266 2034-01-06         804       1051       Boo E        -2
# 10096           5192 2025-08-16         334       1093       Bok N        -2
#
# ...

# %%
df[df['Price'] < 0]
# Out:
# Empty DataFrame
# Columns: [TransactionID, Date, CustomerID, ProductID, ProductName, Quantity, Price, TotalSales, PaymentType, CustomerAge]
# Index: []

# %%
df[df['TotalSales'] < 0]
# Out:
# Empty DataFrame
# Columns: [TransactionID, Date, CustomerID, ProductID, ProductName, Quantity, Price, TotalSales, PaymentType, CustomerAge]
# Index: []

# %%
df[df['CustomerAge'] < 0]
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 6               2996 2031-04-03         571       1086      Book D        15
# 32              4534 2030-10-23         963       1052      Book L         3
# 48              2448 2023-03-07         372       1037      Book D        13
# 64              1497 2025-11-09         279       1084      Book L        -3
# 67              1442 2026-08-14         841       1087      Book T         7
# ...              ...        ...         ...        ...         ...       ...
# 10038           9693 2034-11-10         185       1024       Boo E        13
# 10065           7735 2026-10-11         620       1029       Bok N        -2
# 10068           3006 2025-01-23         261       1011      Book I        15
# 10075           7850 2034-12-25         678       1005      Book S        -5
# 10098            861 2034-04-08         579       1014       Bok N        19
#
# ...

# %%
df['Quantity'] = df['Quantity'].astype(str)

# %%
df['Quantity'] = df['Quantity'].str.replace('-', '')

# %%
df['CustomerAge'] = df['CustomerAge'].astype(str)

# %%
df['CustomerAge'] = df['CustomerAge'].str.replace('-', '')

# %%
df['ProductName'] = df['ProductName'].str.replace('Boo', 'Book')

# %%
df['ProductName'] = df['ProductName'].str.replace('Bok', 'Book')

# %%
df['ProductName'] = df['ProductName'].str.replace(' Book', 'Book')

# %%
df
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName Quantity  \
# 2               2123 2035-05-26         933       1062      Book N        5
# 6               2996 2031-04-03         571       1086     Bookk D       15
# 9               4449 2030-02-05         614       1086     Bookk M        5
# 10              3621 2036-05-08         755       1051      Book E       19
# 11              9211 2035-07-18         361       1020     Bookk O       14
# ...              ...        ...         ...        ...         ...      ...
# 10094           6266 2034-01-06         804       1051      Book E        2
# 10095           5735 2027-04-03          52       1066     Bookk G        1
# 10096           5192 2025-08-16         334       1093      Book N        2
# 10097           5391 2026-06-18         657       1047    Bookkk H        5
# 10098            861 2034-04-08         579       1014      Book N       19
#
#         Price  TotalSales  PaymentType CustomerAge
# ...

# %%
df['ProductName'] = df['ProductName'].str.replace('Bookk', 'Book')

# %%
df['ProductName'] = df['ProductName'].str.replace('Bookkk', 'Book')

# %%
df
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName Quantity  \
# 2               2123 2035-05-26         933       1062      Book N        5
# 6               2996 2031-04-03         571       1086      Book D       15
# 9               4449 2030-02-05         614       1086      Book M        5
# 10              3621 2036-05-08         755       1051      Book E       19
# 11              9211 2035-07-18         361       1020      Book O       14
# ...              ...        ...         ...        ...         ...      ...
# 10094           6266 2034-01-06         804       1051      Book E        2
# 10095           5735 2027-04-03          52       1066      Book G        1
# 10096           5192 2025-08-16         334       1093      Book N        2
# 10097           5391 2026-06-18         657       1047     Bookk H        5
# 10098            861 2034-04-08         579       1014      Book N       19
#
#         Price  TotalSales  PaymentType CustomerAge
# ...

# %%
df['ProductName'] = df['ProductName'].str.replace('Bookk', ' Book')

# %%
df
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName Quantity  \
# 2               2123 2035-05-26         933       1062      Book N        5
# 6               2996 2031-04-03         571       1086      Book D       15
# 9               4449 2030-02-05         614       1086      Book M        5
# 10              3621 2036-05-08         755       1051      Book E       19
# 11              9211 2035-07-18         361       1020      Book O       14
# ...              ...        ...         ...        ...         ...      ...
# 10094           6266 2034-01-06         804       1051      Book E        2
# 10095           5735 2027-04-03          52       1066      Book G        1
# 10096           5192 2025-08-16         334       1093      Book N        2
# 10097           5391 2026-06-18         657       1047      Book H        5
# 10098            861 2034-04-08         579       1014      Book N       19
#
#         Price  TotalSales  PaymentType CustomerAge
# ...

# %%
df.Quantity = df.Quantity.astype(int)

# %%
df.CustomerAge = df.CustomerAge.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5365 entries, 2 to 10098
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionID  5365 non-null   int64
#  1   Date           5365 non-null   datetime64[ns]
#  2   CustomerID     5365 non-null   int64
#  3   ProductID      5365 non-null   int64
#  4   ProductName    5365 non-null   object
#  5   Quantity       5365 non-null   int32
#  6   Price          5365 non-null   float64
#  7   TotalSales     5365 non-null   float64
#  8   PaymentType    5365 non-null   object
#  9   CustomerAge    5365 non-null   int32
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(3), object(2)
# memory usage: 419.1+ KB

# %%
df.TotalSales = df.Quantity * df.Price

# %%
df
# Out:
#        TransactionID       Date  CustomerID  ProductID ProductName  Quantity  \
# 2               2123 2035-05-26         933       1062      Book N         5
# 6               2996 2031-04-03         571       1086      Book D        15
# 9               4449 2030-02-05         614       1086      Book M         5
# 10              3621 2036-05-08         755       1051      Book E        19
# 11              9211 2035-07-18         361       1020      Book O        14
# ...              ...        ...         ...        ...         ...       ...
# 10094           6266 2034-01-06         804       1051      Book E         2
# 10095           5735 2027-04-03          52       1066      Book G         1
# 10096           5192 2025-08-16         334       1093      Book N         2
# 10097           5391 2026-06-18         657       1047      Book H         5
# 10098            861 2034-04-08         579       1014      Book N        19
#
# ...
